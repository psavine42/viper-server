# %%
import os
import sys
import time
import pprint
from collections import Counter, defaultdict
sys.path.append('/home/psavine/source/viper')
sys.path.append("../")


import numpy as np
import importlib
import matplotlib.pyplot as plt

import spec.hvac as thvac
import src.viper as viper

import src.geom as geom
import lib.geo as geo
from src.geomType import GeomType
from scipy import spatial
import src.ui.visual as viz3


from trimesh.path.path import Path
from src.ui import visual
from itertools import chain
from src.ui.visual import meshcat
import shapely.geometry as sg
import trimesh
import pandas as pd
import matplotlib
import math
import spec.scenario as scene
import src.geombase as geombase

RL = importlib.reload
RL(visual)
VIZ = viz3.VIZ

_dir = '/home/psavine/source/viper/data/sample/'
# Out:
# You can open the visualizer by visiting the following URL:
# http://127.0.0.1:7000/static/
# You can open the visualizer by visiting the following URL:
# http://127.0.0.1:7000/static/

# %%
jsond = scene.load_from_json('/home/psavine/source/viper/data/sample/test_sk2.json')

RL(thvac)
train_mesh = thvac.TestTrain.preprocess_(jsond)
print(len(train_mesh))
categories = {x.category for i, x in enumerate(train_mesh)}
categories = {x:i for i, x in enumerate(categories)}
train_ids = {x.id:x for x in train_mesh}
train_ixs = {x.id:i for i, x in enumerate(train_mesh)}
vs2 = viper.IndexSystem()
# ixrs = vs2(train_mesh)
# Out:
# 4439

# %%
[VIZ['mesh/' +x].delete() 
 for x in {x.category for i, x in enumerate(train_mesh)}]
r = [viz3.viz_mesh(x, handle='mesh/' + x.meta['category'], opacity=0.4) 
     for x in train_mesh]
no = []
for p in train_mesh:
    if p.category == 'Pipes':
        if geombase.is_cylinder(p) == False:
            no.append(p)
print(len(no))

[viz3.viz_mesh(x, handle='no', opacity=0.8) for x in no]
# Out:
# 1
# [None]

# %%
V.delete('cadhead')
V.delete('line')

# %%
import dxfgrabber
dxf = dxfgrabber.readfile(_dir + 'WGFPR07m.dxf')
bodies = list(filter(lambda x: isinstance(x, dxfgrabber.dxfentities.Body), dxf.entities))
lines = list(filter(lambda x: isinstance(x, dxfgrabber.dxfentities.Line), dxf.entities))
inserts = list(filter(lambda x: isinstance(x, dxfgrabber.dxfentities.Insert), dxf.entities))

# %%
import src.formats.sat as sab
RL(sab)
reader = sab.SABReader()
acis_ents = [reader.read_single(x.acis) for x in bodies]

# %%
CAD_SCALE = 1 /  25.39999999999999858 
ANGLE = 346.9658914 
np.radians(360 - ANGLE)
# Out:
# 0.227488110132509

# %%
def as_line(this, k='point'):
    pts = this.children_of_type(k)
    if len(pts) == 2:
        p1, p2 = pts
        return geo.Line(geo.Point(p1.geom), geo.Point(p2.geom))

    
def as_linexf(this, trs=np.array([0.,0.,0.]), scale=1.):
    pts = this.children_of_type('point')
    if len(pts) == 2:
        xf = this.children_of_type('transform')
        if len(xf) == 1:
            try:
                p1, p2 = pts
                p11 = (xf[0].apply(p1.geom) *  scale) + trs
                p12 = (xf[0].apply(p2.geom) *  scale) + trs
                return geo.Line(geo.Point(p11), geo.Point(p12))
            except Exception as e:
                return None


def dxf_line_to_line(dxline, bsxf=np.array([0.,0.,0.])):
    p1, p2 = [np.array(x) - bsxf for x in [dxline.start, dxline.end]] 
    return geo.Line(geo.Point(p1), geo.Point(p1))


def pull_points(acis_blocks):
    for i, acis_ents in enumerate(acis_blocks):
        pts = list(filter(lambda x: isinstance(x, sab.ACEllipse), acis_ents))
        if len(pts) == 2:
            p1, p2 = pts
            viz3.viz_line(p1.geom, p2.geom, handle='cad/{}'.format(i))


def viz_pts(pts, handle, clear=True, **kwargs):
    if clear is True:
        VIZ[handle].delete()
    for i, p in enumerate(pts):
        viz3.viz_point(p, handle=handle+'/{}'.format(i), **kwargs)

# %%
CAD_TRANSLATE = -1* np.array(list(as_linexf(acis_ents[0], scale=CAD_SCALE).points[0].coordinates))
# CAD_TRANSLATE[-1] = 0
print(CAD_TRANSLATE)
# Out:
# [-15.4164401  312.02305601 -44.87684516]

# %%
# RL(viz3)
def viz_nodes(ndict):
    if isinstance(ndict, dict):
        nlist = list(ndict.values())
    else:
        nlist = ndict
    viz3.viz_nodes(nlist, 
                   handle='nodes', 
                   thickness=0.08, 
                   opacity=0.6, 
                   clear=True)

def viz_head():
    ddd = [viz3.viz_point(np.array(x.insert) - bsxf,  
                          handle='cadhead/{}'.format(i), 
                          radius=3, 
                          opacity=0.5) 
           for i, x in enumerate(sprks)]
    

def viz_sprink_to_edge(sbests, sprinks):
    VIZ['headlink'].delete()
    for i, (spr_ix, ngh) in enumerate(sbests.items()):
        if ngh is None:
            continue
        g1, g2 = ngh.geom
        pt3d = geo.Point(sprinks[spr_ix])
        cp = geo.Point(g1).midpoint_to(geo.Point(g2))
        viz3.viz(geo.Line(pt3d, cp), handle='headlink/{}'.format(i))

# %% [markdown]
# # Create Final Lines and Visualize

# %%
pipes_lines = list(filter(None, 
                          [as_linexf(x, 
                                     scale=CAD_SCALE, 
                                     trs=CAD_TRANSLATE) 
                           for x in acis_ents]))

pipes_long = [x for x in pipes_lines if 0.2 < x.length ]
print(len(pipes_long))
print(pipes_long[0].numpy)
mv = -1 * pipes_long[0].numpy[0]

VIZ['line'].delete()
viz3.viz_by_index(pipes_long, handle='line', thickness=0.05)
# Out:
# 2387
# [[ 26.59407129 -57.14410531  -2.82960107]
#  [ 26.59407129 -57.14410531  -3.09042784]]

# %% [markdown]
# ## read inserts and visualize

# %%
sprinklers = [x for x in inserts if x.name == '3DM_UPR']
print('num sprinklers' , len(sprinklers))
# print(mv)
print(CAD_TRANSLATE)
sample = np.array(sprinklers[2].insert)
print(sample)
sfn = lambda x: CAD_TRANSLATE  + (np.asarray(x.insert) * CAD_SCALE)

sprinklers2 = np.array(list(map(sfn, sprinklers)))
sprinklers2[:, -1] = 0
print(sprinklers2[2])

viz_pts(sprinklers2, 'cadhead', clear=True, radius=0.2, opacity=0.5)
# Out:
# num sprinklers 1403
# [-15.4164401  312.02305601 -44.87684516]
# [  463.1242295  -8199.00927198  1126.13126295]
# [  2.81679729 -10.77258462   0.        ]

# %%
from scipy.spatial.distance import cdist 
import src.formats.skansk as sks
RL(sks)

def edge_with_id(root_node, eid):
    for n in root_node.__iter__(True, True):
        for e in n.neighbors(True, True, True):
            if e.id == eid:
                return e

def node_with_id(nd, eid):
    for n in nd.__iter__(fwd=True, bkwd=True):
        if n.id == eid:
            return n

        
def apply_fn(root_node, fn, edges=True):
    seen = set()
    for n in root_node.__iter__(True, True):
        for e in n.neighbors(True, True, edges):
            if e.id not in seen:
                seen.add(e.id)
                res = fn(e)
                if res is not None:
                    yield e

                    
def apply_node_edge_fn(root_node, fn):
    seen = set()
    for n in root_node.__iter__(True, True):
        for e in n.neighbors(True, True, True):
            if e.id not in seen:
                seen.add(e.id)
                res = fn(n, e)
                if res is not None:
                    yield res           
        
        
def apply_node_fn(root_node, fn):
    apply_fn(root_node, fn, edges=False)
                    
        
def wrap_yield(fn):
    def run_x(x):
        res = fn(x)
        if res is True:
            return x
        else:
            return None
    return run_x

def viz_edge_attr(root_node, k, **kwargs):
    for n in root_node.__iter__(True, True):
        for e in n.neighbors(True, True, True):
            if  e.get(k) is None:
                continue
            g1, g2 = e.geom
            # pipe = str(e.get('is_pipe', None))
            viz3.viz_line(g1, g2, handle=viz3.as_path(k,  e.id), **kwargs)


def viz_node_attr(root_node, k, v=None, clear=True, **kwargs):
    if clear is True:
        VIZ[k].delete()
    for n in root_node.__iter__(True, True):
        if n.get(k) is None:
            continue
        if v is not None and n.get(k) != v:
            continue
        viz3.viz_point(n.geom, handle=viz3.as_path(k,  n.id), **kwargs)
            
            
            
def as_linecyl(this, trs=np.array([0.,0.,0.]), scale=1.):
    line = (this.line.numpy * scale) + trs
    
    rads = this.radius * scale
    this.line = geo.Line(geo.Point(line[0]), geo.Point(line[1]))
    this.radius = rads
    return this


def fix_triangles(root_node_, result):
    for lres in result:
        tris = [edge_with_id(root_node_, x) for x in lres]
        tris = [x for x in tris if x is not None]
        if len(tris) == 3:
            sks.resolve_triangle(tris)

# %%
from lib.geo import Point, Line
RL(sab)
reader = sab.SABReader()
acis_ents2 = list(filter(lambda x: x.valid is True,
                       map(sab.SACCylinder,
                           acis_ents)))
                           #map(lambda x: reader.read_single(x.acis),
                           #    bodies))))
print(len(acis_ents2))
# Out:
# 14427

# %%
pipes_cyl = list(
    filter(lambda x: x.line.length > x.radius,
    filter(lambda x: x and x.valid is True, 
        map(lambda x: as_linecyl(x,scale=CAD_SCALE, trs=CAD_TRANSLATE) 
                           ,acis_ents2))))
print(len(pipes_cyl))
# Out:
# 8208

# %%
def xfrom(node, scale=1., translate=None, **kwargs):
    nd = np.array(list(node.geom)) * scale
    if translate is not None:
        nd += translate
    node.geom = sks.tuplify(nd)
    return node

# %%
import src.formats.skansk as sks
import src.propogate as gp
from src.structs import Node, Edge
import src.structs.node_utils as gutils
RL(gp)
RL(gutils)
RL(sks)

import src.ui.visual as V

# V.viz_order(rn1, handle='build')
# RL(viz3)
"""
--------------------------------------------------
SAVE THESE SETTINGS. 

FOR FUCKS SAKE DO NOT DELETE !!!!!!!!!!!!!!!

FILTER = 0.3
CONNECT = 0.4
--------------------------------------------------
"""
CAD_ANGLE = np.radians(360 - ANGLE)
REVIT_SCALE = 1 / 0.4799

RL(V)
def save_instr(data, pipes_first=False):
    _COMMS_PATH = '/home/psavine/source/viper/data/out/commands/comms.json'
    if pipes_first is True:
        pipes = [x for x in data if x[0] == 1]
        not_pipes = [x for x in data if x[0] != 1]
        final = pipes + not_pipes
    else:
        final = data
    print('creating insturcionts', len(final))
    with open(_COMMS_PATH, 'w' ) as f:
        json.dump(final, f)
    return final


def build_roots():
    RL(sks)
    FILTER = 0.3
    CONNECT = 0.4
    
     # Build the Graph
    pipes_long = [x for x in pipes_cyl if x.line.length > FILTER]
    pairs2, tree, pts_ind = sks.connect_by_pairs(pipes_long, factor=CONNECT)
    node_dict2 = sks.make_node_dict(pairs2, pts_ind, pipes_long)
    root_nodes = sks.connected_components(list(node_dict2.values()), min_size=2)
    return root_nodes
# Out:
# You can open the visualizer by visiting the following URL:
# http://127.0.0.1:7000/static/

# %%
def viz_kif(root_, k, i, **kwargs):
    # print(k, kwargs.get(k, None))
    if kwargs.get(k, None) is True:
        viz3.viz_iter(root_, handle='grp/{}/{}'.format(i, k), 
                      clear=True, opacity=0.3)
    else:
        viz3.delete(k)

shows = dict(heads=True, edge=True, 
             before=True, buildo=True, tris=True, move=True)

def xprocess(_Nodes, ix=0, v=True, **kwargs):
    # Find Logical Root
    RL(sks)
    RL(gp)
    base_root_node = _Nodes[ix]
    SR = gp.SpatialRoot()
    SR(base_root_node)
    Root = node_with_id(base_root_node, SR.best)

    Mover = gp.Rotator(CAD_ANGLE)
    Elbower = sks.DetectElbows()
    Triangler = sks.DetectTriangles(build=True)
    
    # Direct the edges 
    Root = gp.EdgeDirector()(Root)
    Root = gp.BuildOrder()(Root)

    tree = sks.resolve_heads(Root, sprinklers2)
    # viz_kif(base_root_node, 'heads', ix, **kwargs)
    
    Root = Mover(Root)
    # viz_kif(base_root_node, 'move', ix, **kwargs)
    # V.viz_iter(Root, handle='grp/{}/pre'.format(ix), clear=True, opacity=0.4)
    
    Root = gp.EdgeDirector()(Root)
    Root = gp.BuildOrder()(Root)
    Root = Triangler(Root)
    Root = gp.EdgeDirector()(Root)
    
    
    Root = gp.FunctionQ(sks.add_ups)(Root, h=0.1)
    Root = gp.GraphTrim()(Root, tol=0.01)
    # V.viz_iter(Root, handle='grp/{}/tri'.format(ix), clear=True, opacity=0.4)
    Root = gp.EdgeDirector()(Root)
    Root = gp.FunctionQ(sks.remove_short)(Root, lim=0.25)
    
    FirstEdges = Root.neighbors(edges=True)
    Elbower(FirstEdges)
    
    
    Root = gp.EdgeDirector()(Root)
    Roor = gp.Scale(REVIT_SCALE)(Root)
    Root = sks.LabelConnector()(Root)
    FirstEdges = Root.neighbors(edges=True)
    gp.FunctionQ(sks.align_tap, edges=True)(FirstEdges)
    if v is True:
        V.viz_iter(Root, handle='grp/{}/final'.format(ix), 
                      clear=True, opacity=0.4)

        # viz_node_attr(Root, 'is_head', clear=True, radius=0.02)
    else:
        V.delete('grp/{}/final'.format(ix))
    return Root # , tree

# %%
RL(sks)
[V.delete(x) for x in ['tee1', 'edge', 'tee2', 'tee3', 'long', 'short']]

# visualize
root_nodes = build_roots()
rn0  = xprocess(root_nodes,  ix=0, v=True)

# visualize
# V.viz_order(rn0, clear=True)

RL(revit)
RL(sks)
res = sks.MakeInstructions()(rn0, shrink=-0.05, use_radius=True)
res = save_instr(res)
# viz_edge_attr(rn0, 'tap_edge', clear=True, radius=0.02)
# viz_node_attr(rn0, 'tee_mid', clear=True, radius=0.05)
# viz_node_attr(rn0, 'tee_index', clear=True, radius=0.03)
# Out:
# SpatialRoot seen nodes :  330
# EdgeDirector seen nodes :  330
# BuildOrder seen nodes :  330
# KDTreeIndex seen nodes :  330
# Rotator seen nodes :  239
# EdgeDirector seen nodes :  239
# BuildOrder seen nodes :  239
# DetectTriangles seen nodes :  229
# EdgeDirector seen nodes :  211
# FunctionQ seen nodes :  319
# GraphTrim seen nodes :  319
# EdgeDirector seen nodes :  297
# FunctionQ seen nodes :  290
# DetectElbows seen nodes :  289
# EdgeDirector seen nodes :  290
# Scale seen nodes :  290
# LabelConnector seen nodes :  290
# adjusting  1876959
# adjusting  9618609
# adjusting  9995669
# adjusting  5660645
# adjusting  7254202
# adjusting  9608756
# FunctionQ seen nodes :  289
# MakeInstructions seen nodes :  290
# creating insturcionts 525

# %%
RL(sks)
[V.delete(x) for x in ['tee1', 'edge', 'tee2', 'tee3', 'long', 'short']]

all_res = []
# visualize
root_nodes = build_roots()
for i in range(len(root_nodes)):
    rnX  = xprocess(root_nodes,  ix=i, v=True)

    #RL(revit)
    #RL(sks)
    all_res += sks.MakeInstructions()(rnX, shrink=-0.05, use_radius=True)
    
_ = save_instr(all_res)
# Out:
# SpatialRoot seen nodes :  330
# EdgeDirector seen nodes :  330
# BuildOrder seen nodes :  330
# KDTreeIndex seen nodes :  330
# Rotator seen nodes :  239
# EdgeDirector seen nodes :  239
# BuildOrder seen nodes :  239
# DetectTriangles seen nodes :  229
# EdgeDirector seen nodes :  211
# FunctionQ seen nodes :  319
# GraphTrim seen nodes :  319
# EdgeDirector seen nodes :  297
# FunctionQ seen nodes :  290
# DetectElbows seen nodes :  289
# EdgeDirector seen nodes :  290
# Scale seen nodes :  290
# LabelConnector seen nodes :  290
# adjusting  7031568
# adjusting  6300107
# adjusting  7677216
# adjusting  9201100
# adjusting  7899817
# adjusting  2507759
# FunctionQ seen nodes :  289
# MakeInstructions seen nodes :  290
# SpatialRoot seen nodes :  452
# EdgeDirector seen nodes :  452
# BuildOrder seen nodes :  452
# KDTreeIndex seen nodes :  452
# Rotator seen nodes :  322
# EdgeDirector seen nodes :  322
# BuildOrder seen nodes :  322
# DetectTriangles seen nodes :  312
# EdgeDirector seen nodes :  287
# FunctionQ seen nodes :  443
# GraphTrim seen nodes :  443
# EdgeDirector seen nodes :  426
# FunctionQ seen nodes :  417
# DetectElbows seen nodes :  416
# EdgeDirector seen nodes :  417
# Scale seen nodes :  417
# LabelConnector seen nodes :  417
# adjusting  3473384
# adjusting  3545112
# adjusting  6909264
# adjusting  744440
# adjusting  8983999
# adjusting  9574605
# adjusting  6627453
# adjusting  7386164
# adjusting  4136117
# adjusting  3755661
# adjusting  5047771
# adjusting  3416743
# FunctionQ seen nodes :  416
# MakeInstructions seen nodes :  417
# SpatialRoot seen nodes :  110
# EdgeDirector seen nodes :  110
# BuildOrder seen nodes :  110
# KDTreeIndex seen nodes :  110
# Rotator seen nodes :  74
# EdgeDirector seen nodes :  74
# BuildOrder seen nodes :  74
# DetectTriangles seen nodes :  74
# EdgeDirector seen nodes :  68
# FunctionQ seen nodes :  110
# GraphTrim seen nodes :  110
# EdgeDirector seen nodes :  106
# FunctionQ seen nodes :  106
# DetectElbows seen nodes :  105
# EdgeDirector seen nodes :  106
# Scale seen nodes :  106
# LabelConnector seen nodes :  106
# FunctionQ seen nodes :  105
# MakeInstructions seen nodes :  106
# SpatialRoot seen nodes :  22
# EdgeDirector seen nodes :  22
# BuildOrder seen nodes :  22
# KDTreeIndex seen nodes :  22
# Rotator seen nodes :  16
# EdgeDirector seen nodes :  16
# BuildOrder seen nodes :  16
# DetectTriangles seen nodes :  15
# EdgeDirector seen nodes :  14
# FunctionQ seen nodes :  22
# GraphTrim seen nodes :  22
# EdgeDirector seen nodes :  22
# FunctionQ seen nodes :  22
# DetectElbows seen nodes :  21
# EdgeDirector seen nodes :  22
# Scale seen nodes :  22
# LabelConnector seen nodes :  22
# adjusting  6701578
# FunctionQ seen nodes :  21
# MakeInstructions seen nodes :  22
# SpatialRoot seen nodes :  158
# EdgeDirector seen nodes :  158
# BuildOrder seen nodes :  158
# KDTreeIndex seen nodes :  158
# Rotator seen nodes :  116
# EdgeDirector seen nodes :  116
# BuildOrder seen nodes :  116
# DetectTriangles seen nodes :  116
# EdgeDirector seen nodes :  107
# FunctionQ seen nodes :  157
# GraphTrim seen nodes :  157
# EdgeDirector seen nodes :  150
# FunctionQ seen nodes :  150
# DetectElbows seen nodes :  149
# EdgeDirector seen nodes :  150
# Scale seen nodes :  150
# LabelConnector seen nodes :  150
# adjusting  3250453
# adjusting  9611235
# adjusting  4779021
# adjusting  4882881
# adjusting  1681658
# adjusting  8096228
# FunctionQ seen nodes :  149
# MakeInstructions seen nodes :  150
# SpatialRoot seen nodes :  104
# EdgeDirector seen nodes :  104
# BuildOrder seen nodes :  104
# KDTreeIndex seen nodes :  104
# Rotator seen nodes :  69
# EdgeDirector seen nodes :  69
# BuildOrder seen nodes :  69
# DetectTriangles seen nodes :  69
# EdgeDirector seen nodes :  63
# FunctionQ seen nodes :  105
# GraphTrim seen nodes :  105
# EdgeDirector seen nodes :  101
# FunctionQ seen nodes :  101
# DetectElbows seen nodes :  100
# EdgeDirector seen nodes :  101
# Scale seen nodes :  101
# LabelConnector seen nodes :  101
# FunctionQ seen nodes :  100
# MakeInstructions seen nodes :  101
# SpatialRoot seen nodes :  120
# EdgeDirector seen nodes :  120
# BuildOrder seen nodes :  120
# KDTreeIndex seen nodes :  120
# Rotator seen nodes :  80
# EdgeDirector seen nodes :  80
# BuildOrder seen nodes :  80
# DetectTriangles seen nodes :  80
# EdgeDirector seen nodes :  72
# FunctionQ seen nodes :  120
# GraphTrim seen nodes :  120
# EdgeDirector seen nodes :  116
# FunctionQ seen nodes :  116
# DetectElbows seen nodes :  115
# EdgeDirector seen nodes :  116
# Scale seen nodes :  116
# LabelConnector seen nodes :  116
# adjusting  5499971
# adjusting  32582
# adjusting  396849
# FunctionQ seen nodes :  115
# MakeInstructions seen nodes :  116
# SpatialRoot seen nodes :  104
# EdgeDirector seen nodes :  104
# BuildOrder seen nodes :  104
# KDTreeIndex seen nodes :  104
# Rotator seen nodes :  69
# EdgeDirector seen nodes :  69
# BuildOrder seen nodes :  69
# DetectTriangles seen nodes :  69
# EdgeDirector seen nodes :  63
# FunctionQ seen nodes :  105
# GraphTrim seen nodes :  105
# EdgeDirector seen nodes :  101
# FunctionQ seen nodes :  101
# DetectElbows seen nodes :  100
# EdgeDirector seen nodes :  101
# Scale seen nodes :  101
# LabelConnector seen nodes :  101
# adjusting  5858042
# adjusting  3790389
# adjusting  4730213
# FunctionQ seen nodes :  100
# MakeInstructions seen nodes :  101
# SpatialRoot seen nodes :  120
# EdgeDirector seen nodes :  120
# BuildOrder seen nodes :  120
# KDTreeIndex seen nodes :  120
# Rotator seen nodes :  80
# EdgeDirector seen nodes :  80
# BuildOrder seen nodes :  80
# DetectTriangles seen nodes :  80
# EdgeDirector seen nodes :  72
# FunctionQ seen nodes :  120
# GraphTrim seen nodes :  120
# EdgeDirector seen nodes :  116
# FunctionQ seen nodes :  116
# DetectElbows seen nodes :  115
# EdgeDirector seen nodes :  116
# Scale seen nodes :  116
# LabelConnector seen nodes :  116
# FunctionQ seen nodes :  115
# MakeInstructions seen nodes :  116
# SpatialRoot seen nodes :  112
# EdgeDirector seen nodes :  112
# BuildOrder seen nodes :  112
# KDTreeIndex seen nodes :  112
# Rotator seen nodes :  76
# EdgeDirector seen nodes :  76
# BuildOrder seen nodes :  76
# DetectTriangles seen nodes :  76
# EdgeDirector seen nodes :  70
# FunctionQ seen nodes :  112
# GraphTrim seen nodes :  112
# EdgeDirector seen nodes :  108
# FunctionQ seen nodes :  108
# DetectElbows seen nodes :  107
# EdgeDirector seen nodes :  108
# Scale seen nodes :  108
# LabelConnector seen nodes :  108
# adjusting  8173299
# adjusting  6965855
# adjusting  7609454
# FunctionQ seen nodes :  107
# MakeInstructions seen nodes :  108
# SpatialRoot seen nodes :  60
# EdgeDirector seen nodes :  60
# BuildOrder seen nodes :  60
# KDTreeIndex seen nodes :  60
# Rotator seen nodes :  60
# EdgeDirector seen nodes :  60
# BuildOrder seen nodes :  60
# DetectTriangles seen nodes :  60
# EdgeDirector seen nodes :  56
# FunctionQ seen nodes :  56
# GraphTrim seen nodes :  56
# EdgeDirector seen nodes :  20
# FunctionQ seen nodes :  20
# DetectElbows seen nodes :  19
# EdgeDirector seen nodes :  20
# Scale seen nodes :  20
# LabelConnector seen nodes :  20
# adjusting  9021446
# adjusting  3240661
# adjusting  8899037
# adjusting  4320592
# adjusting  2015492
# adjusting  5425581
# adjusting  648698
# adjusting  1924571
# FunctionQ seen nodes :  19
# MakeInstructions seen nodes :  20
# SpatialRoot seen nodes :  118
# EdgeDirector seen nodes :  118
# BuildOrder seen nodes :  118
# KDTreeIndex seen nodes :  118
# Rotator seen nodes :  79
# EdgeDirector seen nodes :  79
# BuildOrder seen nodes :  79
# DetectTriangles seen nodes :  79
# EdgeDirector seen nodes :  71
# FunctionQ seen nodes :  118
# GraphTrim seen nodes :  118
# EdgeDirector seen nodes :  114
# FunctionQ seen nodes :  114
# DetectElbows seen nodes :  113
# EdgeDirector seen nodes :  114
# Scale seen nodes :  114
# LabelConnector seen nodes :  114
# FunctionQ seen nodes :  113
# MakeInstructions seen nodes :  114
# SpatialRoot seen nodes :  292
# EdgeDirector seen nodes :  292
# BuildOrder seen nodes :  292
# KDTreeIndex seen nodes :  292
# Rotator seen nodes :  201
# EdgeDirector seen nodes :  201
# BuildOrder seen nodes :  201
# DetectTriangles seen nodes :  200
# EdgeDirector seen nodes :  179
# FunctionQ seen nodes :  288
# GraphTrim seen nodes :  288
# EdgeDirector seen nodes :  278
# FunctionQ seen nodes :  277
# DetectElbows seen nodes :  276
# EdgeDirector seen nodes :  277
# Scale seen nodes :  277
# LabelConnector seen nodes :  277
# adjusting  3549173
# adjusting  5941124
# adjusting  6088088
# adjusting  9384841
# adjusting  3653296
# adjusting  4599832
# adjusting  7124893
# adjusting  5761791
# adjusting  1791266
# adjusting  3001290
# adjusting  9986832
# adjusting  6263121
# adjusting  820215
# adjusting  4496600
# FunctionQ seen nodes :  276
# MakeInstructions seen nodes :  277
# SpatialRoot seen nodes :  120
# EdgeDirector seen nodes :  120
# BuildOrder seen nodes :  120
# KDTreeIndex seen nodes :  120
# Rotator seen nodes :  80
# EdgeDirector seen nodes :  80
# BuildOrder seen nodes :  80
# DetectTriangles seen nodes :  80
# EdgeDirector seen nodes :  72
# FunctionQ seen nodes :  120
# GraphTrim seen nodes :  120
# EdgeDirector seen nodes :  116
# FunctionQ seen nodes :  116
# DetectElbows seen nodes :  115
# EdgeDirector seen nodes :  116
# Scale seen nodes :  116
# LabelConnector seen nodes :  116
# FunctionQ seen nodes :  115
# MakeInstructions seen nodes :  116
# SpatialRoot seen nodes :  120
# EdgeDirector seen nodes :  120
# BuildOrder seen nodes :  120
# KDTreeIndex seen nodes :  120
# Rotator seen nodes :  80
# EdgeDirector seen nodes :  80
# BuildOrder seen nodes :  80
# DetectTriangles seen nodes :  80
# EdgeDirector seen nodes :  72
# FunctionQ seen nodes :  120
# GraphTrim seen nodes :  120
# EdgeDirector seen nodes :  116
# FunctionQ seen nodes :  116
# DetectElbows seen nodes :  115
# EdgeDirector seen nodes :  116
# Scale seen nodes :  116
# LabelConnector seen nodes :  116
# adjusting  4438220
# adjusting  9687421
# adjusting  5540172
# FunctionQ seen nodes :  115
# MakeInstructions seen nodes :  116
# SpatialRoot seen nodes :  102
# EdgeDirector seen nodes :  102
# BuildOrder seen nodes :  102
# KDTreeIndex seen nodes :  102
# Rotator seen nodes :  68
# EdgeDirector seen nodes :  68
# BuildOrder seen nodes :  68
# DetectTriangles seen nodes :  68
# EdgeDirector seen nodes :  62
# FunctionQ seen nodes :  103
# GraphTrim seen nodes :  103
# EdgeDirector seen nodes :  99
# FunctionQ seen nodes :  99
# DetectElbows seen nodes :  98
# EdgeDirector seen nodes :  99
# Scale seen nodes :  99
# LabelConnector seen nodes :  99
# FunctionQ seen nodes :  98
# MakeInstructions seen nodes :  99
# SpatialRoot seen nodes :  12
# EdgeDirector seen nodes :  12
# BuildOrder seen nodes :  12
# KDTreeIndex seen nodes :  12
# Rotator seen nodes :  7
# EdgeDirector seen nodes :  7
# BuildOrder seen nodes :  7
# DetectTriangles seen nodes :  7
# EdgeDirector seen nodes :  7
# FunctionQ seen nodes :  13
# GraphTrim seen nodes :  13
# EdgeDirector seen nodes :  13
# FunctionQ seen nodes :  13
# DetectElbows seen nodes :  12
# EdgeDirector seen nodes :  13
# Scale seen nodes :  13
# LabelConnector seen nodes :  13
# FunctionQ seen nodes :  12
# MakeInstructions seen nodes :  13
# SpatialRoot seen nodes :  84
# EdgeDirector seen nodes :  84
# BuildOrder seen nodes :  84
# KDTreeIndex seen nodes :  84
# Rotator seen nodes :  59
# EdgeDirector seen nodes :  59
# BuildOrder seen nodes :  59
# DetectTriangles seen nodes :  58
# EdgeDirector seen nodes :  53
# FunctionQ seen nodes :  83
# GraphTrim seen nodes :  83
# EdgeDirector seen nodes :  83
# FunctionQ seen nodes :  83
# DetectElbows seen nodes :  82
# EdgeDirector seen nodes :  83
# Scale seen nodes :  83
# LabelConnector seen nodes :  83
# adjusting  6744606
# adjusting  634937
# adjusting  6049000
# FunctionQ seen nodes :  82
# MakeInstructions seen nodes :  83
# SpatialRoot seen nodes :  120
# EdgeDirector seen nodes :  120
# BuildOrder seen nodes :  120
# KDTreeIndex seen nodes :  120
# Rotator seen nodes :  80
# EdgeDirector seen nodes :  80
# BuildOrder seen nodes :  80
# DetectTriangles seen nodes :  80
# EdgeDirector seen nodes :  72
# FunctionQ seen nodes :  120
# GraphTrim seen nodes :  120
# EdgeDirector seen nodes :  116
# FunctionQ seen nodes :  116
# DetectElbows seen nodes :  115
# EdgeDirector seen nodes :  116
# Scale seen nodes :  116
# LabelConnector seen nodes :  116
# adjusting  7709118
# adjusting  6776985
# adjusting  2371102
# FunctionQ seen nodes :  115
# MakeInstructions seen nodes :  116
# SpatialRoot seen nodes :  74
# EdgeDirector seen nodes :  74
# BuildOrder seen nodes :  74
# KDTreeIndex seen nodes :  74
# Rotator seen nodes :  55
# EdgeDirector seen nodes :  55
# BuildOrder seen nodes :  55
# DetectTriangles seen nodes :  55
# EdgeDirector seen nodes :  50
# FunctionQ seen nodes :  74
# GraphTrim seen nodes :  74
# EdgeDirector seen nodes :  71
# FunctionQ seen nodes :  71
# DetectElbows seen nodes :  70
# EdgeDirector seen nodes :  71
# Scale seen nodes :  71
# LabelConnector seen nodes :  71
# adjusting  3815272
# adjusting  5355662
# FunctionQ seen nodes :  70
# MakeInstructions seen nodes :  71
# SpatialRoot seen nodes :  104
# EdgeDirector seen nodes :  104
# BuildOrder seen nodes :  104
# KDTreeIndex seen nodes :  104
# Rotator seen nodes :  69
# EdgeDirector seen nodes :  69
# BuildOrder seen nodes :  69
# DetectTriangles seen nodes :  69
# EdgeDirector seen nodes :  63
# FunctionQ seen nodes :  105
# GraphTrim seen nodes :  105
# EdgeDirector seen nodes :  101
# FunctionQ seen nodes :  101
# DetectElbows seen nodes :  100
# EdgeDirector seen nodes :  101
# Scale seen nodes :  101
# LabelConnector seen nodes :  101
# FunctionQ seen nodes :  100
# MakeInstructions seen nodes :  101
# SpatialRoot seen nodes :  120
# EdgeDirector seen nodes :  120
# BuildOrder seen nodes :  120
# KDTreeIndex seen nodes :  120
# Rotator seen nodes :  80
# EdgeDirector seen nodes :  80
# BuildOrder seen nodes :  80
# DetectTriangles seen nodes :  80
# EdgeDirector seen nodes :  72
# FunctionQ seen nodes :  120
# GraphTrim seen nodes :  120
# EdgeDirector seen nodes :  116
# FunctionQ seen nodes :  116
# DetectElbows seen nodes :  115
# EdgeDirector seen nodes :  116
# Scale seen nodes :  116
# LabelConnector seen nodes :  116
# adjusting  6704742
# adjusting  4223433
# adjusting  8128371
# FunctionQ seen nodes :  115
# MakeInstructions seen nodes :  116
# SpatialRoot seen nodes :  44
# EdgeDirector seen nodes :  44
# BuildOrder seen nodes :  44
# KDTreeIndex seen nodes :  44
# Rotator seen nodes :  29
# EdgeDirector seen nodes :  29
# BuildOrder seen nodes :  29
# DetectTriangles seen nodes :  29
# EdgeDirector seen nodes :  27
# FunctionQ seen nodes :  44
# GraphTrim seen nodes :  44
# EdgeDirector seen nodes :  44
# FunctionQ seen nodes :  44
# DetectElbows seen nodes :  43
# EdgeDirector seen nodes :  44
# Scale seen nodes :  44
# LabelConnector seen nodes :  44
# FunctionQ seen nodes :  43
# MakeInstructions seen nodes :  44
# SpatialRoot seen nodes :  120
# EdgeDirector seen nodes :  120
# BuildOrder seen nodes :  120
# KDTreeIndex seen nodes :  120
# Rotator seen nodes :  80
# EdgeDirector seen nodes :  80
# BuildOrder seen nodes :  80
# DetectTriangles seen nodes :  80
# EdgeDirector seen nodes :  72
# FunctionQ seen nodes :  120
# GraphTrim seen nodes :  120
# EdgeDirector seen nodes :  116
# FunctionQ seen nodes :  116
# DetectElbows seen nodes :  115
# EdgeDirector seen nodes :  116
# Scale seen nodes :  116
# LabelConnector seen nodes :  116
# FunctionQ seen nodes :  115
# MakeInstructions seen nodes :  116
# SpatialRoot seen nodes :  104
# EdgeDirector seen nodes :  104
# BuildOrder seen nodes :  104
# KDTreeIndex seen nodes :  104
# Rotator seen nodes :  69
# EdgeDirector seen nodes :  69
# BuildOrder seen nodes :  69
# DetectTriangles seen nodes :  69
# EdgeDirector seen nodes :  63
# FunctionQ seen nodes :  105
# GraphTrim seen nodes :  105
# EdgeDirector seen nodes :  101
# FunctionQ seen nodes :  101
# DetectElbows seen nodes :  100
# EdgeDirector seen nodes :  101
# Scale seen nodes :  101
# LabelConnector seen nodes :  101
# FunctionQ seen nodes :  100
# MakeInstructions seen nodes :  101
# SpatialRoot seen nodes :  104
# EdgeDirector seen nodes :  104
# BuildOrder seen nodes :  104
# KDTreeIndex seen nodes :  104
# Rotator seen nodes :  69
# EdgeDirector seen nodes :  69
# BuildOrder seen nodes :  69
# DetectTriangles seen nodes :  69
# EdgeDirector seen nodes :  63
# FunctionQ seen nodes :  105
# GraphTrim seen nodes :  105
# EdgeDirector seen nodes :  101
# FunctionQ seen nodes :  101
# DetectElbows seen nodes :  100
# EdgeDirector seen nodes :  101
# Scale seen nodes :  101
# LabelConnector seen nodes :  101
# FunctionQ seen nodes :  100
# MakeInstructions seen nodes :  101
# SpatialRoot seen nodes :  46
# EdgeDirector seen nodes :  46
# BuildOrder seen nodes :  46
# KDTreeIndex seen nodes :  46
# Rotator seen nodes :  31
# EdgeDirector seen nodes :  31
# BuildOrder seen nodes :  31
# DetectTriangles seen nodes :  31
# EdgeDirector seen nodes :  28
# FunctionQ seen nodes :  46
# GraphTrim seen nodes :  46
# EdgeDirector seen nodes :  46
# FunctionQ seen nodes :  46
# DetectElbows seen nodes :  45
# EdgeDirector seen nodes :  46
# Scale seen nodes :  46
# LabelConnector seen nodes :  46
# FunctionQ seen nodes :  45
# MakeInstructions seen nodes :  46
# SpatialRoot seen nodes :  44
# EdgeDirector seen nodes :  44
# BuildOrder seen nodes :  44
# KDTreeIndex seen nodes :  44
# Rotator seen nodes :  29
# EdgeDirector seen nodes :  29
# BuildOrder seen nodes :  29
# DetectTriangles seen nodes :  29
# EdgeDirector seen nodes :  27
# FunctionQ seen nodes :  45
# GraphTrim seen nodes :  45
# EdgeDirector seen nodes :  45
# FunctionQ seen nodes :  45
# DetectElbows seen nodes :  44
# EdgeDirector seen nodes :  45
# Scale seen nodes :  45
# LabelConnector seen nodes :  45
# adjusting  2166319
# adjusting  4798901
# FunctionQ seen nodes :  44
# MakeInstructions seen nodes :  45
# SpatialRoot seen nodes :  12
# EdgeDirector seen nodes :  12
# BuildOrder seen nodes :  12
# KDTreeIndex seen nodes :  12
# Rotator seen nodes :  7
# EdgeDirector seen nodes :  7
# BuildOrder seen nodes :  7
# DetectTriangles seen nodes :  7
# EdgeDirector seen nodes :  7
# FunctionQ seen nodes :  13
# GraphTrim seen nodes :  13
# EdgeDirector seen nodes :  13
# FunctionQ seen nodes :  13
# DetectElbows seen nodes :  12
# EdgeDirector seen nodes :  13
# Scale seen nodes :  13
# LabelConnector seen nodes :  13
# FunctionQ seen nodes :  12
# MakeInstructions seen nodes :  13
# SpatialRoot seen nodes :  60
# EdgeDirector seen nodes :  60
# BuildOrder seen nodes :  60
# KDTreeIndex seen nodes :  60
# Rotator seen nodes :  40
# EdgeDirector seen nodes :  40
# BuildOrder seen nodes :  40
# DetectTriangles seen nodes :  40
# EdgeDirector seen nodes :  36
# FunctionQ seen nodes :  60
# GraphTrim seen nodes :  60
# EdgeDirector seen nodes :  60
# FunctionQ seen nodes :  60
# DetectElbows seen nodes :  59
# EdgeDirector seen nodes :  60
# Scale seen nodes :  60
# LabelConnector seen nodes :  60
# adjusting  3743568
# adjusting  7715381
# FunctionQ seen nodes :  59
# MakeInstructions seen nodes :  60
# SpatialRoot seen nodes :  4
# EdgeDirector seen nodes :  4
# BuildOrder seen nodes :  4
# KDTreeIndex seen nodes :  4
# Rotator seen nodes :  4
# EdgeDirector seen nodes :  4
# BuildOrder seen nodes :  4
# DetectTriangles seen nodes :  4
# EdgeDirector seen nodes :  4
# FunctionQ seen nodes :  5
# GraphTrim seen nodes :  5
# EdgeDirector seen nodes :  5
# FunctionQ seen nodes :  5
# DetectElbows seen nodes :  4
# EdgeDirector seen nodes :  5
# Scale seen nodes :  5
# LabelConnector seen nodes :  5
# FunctionQ seen nodes :  4
# MakeInstructions seen nodes :  5
# SpatialRoot seen nodes :  60
# EdgeDirector seen nodes :  60
# BuildOrder seen nodes :  60
# KDTreeIndex seen nodes :  60
# Rotator seen nodes :  40
# EdgeDirector seen nodes :  40
# BuildOrder seen nodes :  40
# DetectTriangles seen nodes :  40
# EdgeDirector seen nodes :  36
# FunctionQ seen nodes :  60
# GraphTrim seen nodes :  60
# EdgeDirector seen nodes :  60
# FunctionQ seen nodes :  60
# DetectElbows seen nodes :  59
# EdgeDirector seen nodes :  60
# Scale seen nodes :  60
# LabelConnector seen nodes :  60
# FunctionQ seen nodes :  59
# MakeInstructions seen nodes :  60
# SpatialRoot seen nodes :  12
# EdgeDirector seen nodes :  12
# BuildOrder seen nodes :  12
# KDTreeIndex seen nodes :  12
# Rotator seen nodes :  12
# EdgeDirector seen nodes :  12
# BuildOrder seen nodes :  12
# DetectTriangles seen nodes :  12
# EdgeDirector seen nodes :  12
# FunctionQ seen nodes :  12
# GraphTrim seen nodes :  12
# EdgeDirector seen nodes :  6
# FunctionQ seen nodes :  6
# DetectElbows seen nodes :  5
# EdgeDirector seen nodes :  6
# Scale seen nodes :  6
# LabelConnector seen nodes :  6
# FunctionQ seen nodes :  5
# MakeInstructions seen nodes :  6
# SpatialRoot seen nodes :  12
# EdgeDirector seen nodes :  12
# BuildOrder seen nodes :  12
# KDTreeIndex seen nodes :  12
# Rotator seen nodes :  7
# EdgeDirector seen nodes :  7
# BuildOrder seen nodes :  7
# DetectTriangles seen nodes :  7
# EdgeDirector seen nodes :  7
# FunctionQ seen nodes :  13
# GraphTrim seen nodes :  13
# EdgeDirector seen nodes :  13
# FunctionQ seen nodes :  13
# DetectElbows seen nodes :  12
# EdgeDirector seen nodes :  13
# Scale seen nodes :  13
# LabelConnector seen nodes :  13
# FunctionQ seen nodes :  12
# MakeInstructions seen nodes :  13
# SpatialRoot seen nodes :  8
# EdgeDirector seen nodes :  8
# BuildOrder seen nodes :  8
# KDTreeIndex seen nodes :  8
# Rotator seen nodes :  8
# EdgeDirector seen nodes :  8
# BuildOrder seen nodes :  8
# DetectTriangles seen nodes :  7
# EdgeDirector seen nodes :  6
# FunctionQ seen nodes :  6
# GraphTrim seen nodes :  6
# EdgeDirector seen nodes :  6
# FunctionQ seen nodes :  6
# DetectElbows seen nodes :  5
# EdgeDirector seen nodes :  6
# Scale seen nodes :  6
# LabelConnector seen nodes :  6
# adjusting  9584830
# FunctionQ seen nodes :  5
# MakeInstructions seen nodes :  6
# SpatialRoot seen nodes :  12
# EdgeDirector seen nodes :  12
# BuildOrder seen nodes :  12
# KDTreeIndex seen nodes :  12
# Rotator seen nodes :  12
# EdgeDirector seen nodes :  12
# BuildOrder seen nodes :  12
# DetectTriangles seen nodes :  12
# EdgeDirector seen nodes :  12
# FunctionQ seen nodes :  12
# GraphTrim seen nodes :  12
# EdgeDirector seen nodes :  12
# FunctionQ seen nodes :  7
# DetectElbows seen nodes :  6
# EdgeDirector seen nodes :  7
# Scale seen nodes :  7
# LabelConnector seen nodes :  7
# FunctionQ seen nodes :  6
# MakeInstructions seen nodes :  7
# SpatialRoot seen nodes :  12
# EdgeDirector seen nodes :  12
# BuildOrder seen nodes :  12
# KDTreeIndex seen nodes :  12
# Rotator seen nodes :  7
# EdgeDirector seen nodes :  7
# BuildOrder seen nodes :  7
# DetectTriangles seen nodes :  7
# EdgeDirector seen nodes :  7
# FunctionQ seen nodes :  13
# GraphTrim seen nodes :  13
# EdgeDirector seen nodes :  13
# FunctionQ seen nodes :  13
# DetectElbows seen nodes :  12
# EdgeDirector seen nodes :  13
# Scale seen nodes :  13
# LabelConnector seen nodes :  13
# FunctionQ seen nodes :  12
# MakeInstructions seen nodes :  13
# SpatialRoot seen nodes :  10
# EdgeDirector seen nodes :  10
# BuildOrder seen nodes :  10
# KDTreeIndex seen nodes :  10
# Rotator seen nodes :  10
# EdgeDirector seen nodes :  10
# BuildOrder seen nodes :  10
# DetectTriangles seen nodes :  10
# EdgeDirector seen nodes :  10
# FunctionQ seen nodes :  10
# GraphTrim seen nodes :  10
# EdgeDirector seen nodes :  10
# FunctionQ seen nodes :  10
# DetectElbows seen nodes :  9
# EdgeDirector seen nodes :  10
# Scale seen nodes :  10
# LabelConnector seen nodes :  10
# adjusting  3716356
# adjusting  5252204
# FunctionQ seen nodes :  9
# MakeInstructions seen nodes :  10
# SpatialRoot seen nodes :  12
# EdgeDirector seen nodes :  12
# BuildOrder seen nodes :  12
# KDTreeIndex seen nodes :  12
# Rotator seen nodes :  7
# EdgeDirector seen nodes :  7
# BuildOrder seen nodes :  7
# DetectTriangles seen nodes :  7
# EdgeDirector seen nodes :  7
# FunctionQ seen nodes :  13
# GraphTrim seen nodes :  13
# EdgeDirector seen nodes :  13
# FunctionQ seen nodes :  13
# DetectElbows seen nodes :  12
# EdgeDirector seen nodes :  13
# Scale seen nodes :  13
# LabelConnector seen nodes :  13
# FunctionQ seen nodes :  12
# MakeInstructions seen nodes :  13
# SpatialRoot seen nodes :  12
# EdgeDirector seen nodes :  12
# BuildOrder seen nodes :  12
# KDTreeIndex seen nodes :  12
# Rotator seen nodes :  7
# EdgeDirector seen nodes :  7
# BuildOrder seen nodes :  7
# DetectTriangles seen nodes :  7
# EdgeDirector seen nodes :  7
# FunctionQ seen nodes :  13
# GraphTrim seen nodes :  13
# EdgeDirector seen nodes :  13
# FunctionQ seen nodes :  13
# DetectElbows seen nodes :  12
# EdgeDirector seen nodes :  13
# Scale seen nodes :  13
# LabelConnector seen nodes :  13
# FunctionQ seen nodes :  12
# MakeInstructions seen nodes :  13
# SpatialRoot seen nodes :  12
# EdgeDirector seen nodes :  12
# BuildOrder seen nodes :  12
# KDTreeIndex seen nodes :  12
# Rotator seen nodes :  7
# EdgeDirector seen nodes :  7
# BuildOrder seen nodes :  7
# DetectTriangles seen nodes :  7
# EdgeDirector seen nodes :  7
# FunctionQ seen nodes :  13
# GraphTrim seen nodes :  13
# EdgeDirector seen nodes :  13
# FunctionQ seen nodes :  13
# DetectElbows seen nodes :  12
# EdgeDirector seen nodes :  13
# Scale seen nodes :  13
# LabelConnector seen nodes :  13
# FunctionQ seen nodes :  12
# MakeInstructions seen nodes :  13
# SpatialRoot seen nodes :  12
# EdgeDirector seen nodes :  12
# BuildOrder seen nodes :  12
# KDTreeIndex seen nodes :  12
# Rotator seen nodes :  12
# EdgeDirector seen nodes :  12
# BuildOrder seen nodes :  12
# DetectTriangles seen nodes :  12
# EdgeDirector seen nodes :  12
# FunctionQ seen nodes :  12
# GraphTrim seen nodes :  12
# EdgeDirector seen nodes :  12
# FunctionQ seen nodes :  7
# DetectElbows seen nodes :  6
# EdgeDirector seen nodes :  7
# Scale seen nodes :  7
# LabelConnector seen nodes :  7
# FunctionQ seen nodes :  6
# MakeInstructions seen nodes :  7
# SpatialRoot seen nodes :  8
# EdgeDirector seen nodes :  8
# BuildOrder seen nodes :  8
# KDTreeIndex seen nodes :  8
# Rotator seen nodes :  6
# EdgeDirector seen nodes :  6
# BuildOrder seen nodes :  6
# DetectTriangles seen nodes :  6
# EdgeDirector seen nodes :  6
# FunctionQ seen nodes :  9
# GraphTrim seen nodes :  9
# EdgeDirector seen nodes :  9
# FunctionQ seen nodes :  9
# DetectElbows seen nodes :  8
# EdgeDirector seen nodes :  9
# Scale seen nodes :  9
# LabelConnector seen nodes :  9
# FunctionQ seen nodes :  8
# MakeInstructions seen nodes :  9
# SpatialRoot seen nodes :  12
# EdgeDirector seen nodes :  12
# BuildOrder seen nodes :  12
# KDTreeIndex seen nodes :  12
# Rotator seen nodes :  12
# EdgeDirector seen nodes :  12
# BuildOrder seen nodes :  12
# DetectTriangles seen nodes :  12
# EdgeDirector seen nodes :  12
# FunctionQ seen nodes :  12
# GraphTrim seen nodes :  12
# EdgeDirector seen nodes :  12
# FunctionQ seen nodes :  7
# DetectElbows seen nodes :  6
# EdgeDirector seen nodes :  7
# Scale seen nodes :  7
# LabelConnector seen nodes :  7
# FunctionQ seen nodes :  6
# MakeInstructions seen nodes :  7
# SpatialRoot seen nodes :  12
# EdgeDirector seen nodes :  12
# BuildOrder seen nodes :  12
# KDTreeIndex seen nodes :  12
# Rotator seen nodes :  7
# EdgeDirector seen nodes :  7
# BuildOrder seen nodes :  7
# DetectTriangles seen nodes :  7
# EdgeDirector seen nodes :  7
# FunctionQ seen nodes :  13
# GraphTrim seen nodes :  13
# EdgeDirector seen nodes :  13
# FunctionQ seen nodes :  13
# DetectElbows seen nodes :  12
# EdgeDirector seen nodes :  13
# Scale seen nodes :  13
# LabelConnector seen nodes :  13
# FunctionQ seen nodes :  12
# MakeInstructions seen nodes :  13
# SpatialRoot seen nodes :  12
# EdgeDirector seen nodes :  12
# BuildOrder seen nodes :  12
# KDTreeIndex seen nodes :  12
# Rotator seen nodes :  12
# EdgeDirector seen nodes :  12
# BuildOrder seen nodes :  12
# DetectTriangles seen nodes :  12
# EdgeDirector seen nodes :  12
# FunctionQ seen nodes :  12
# GraphTrim seen nodes :  12
# EdgeDirector seen nodes :  12
# FunctionQ seen nodes :  7
# DetectElbows seen nodes :  6
# EdgeDirector seen nodes :  7
# Scale seen nodes :  7
# LabelConnector seen nodes :  7
# FunctionQ seen nodes :  6
# MakeInstructions seen nodes :  7
# SpatialRoot seen nodes :  12
# EdgeDirector seen nodes :  12
# BuildOrder seen nodes :  12
# KDTreeIndex seen nodes :  12
# Rotator seen nodes :  7
# EdgeDirector seen nodes :  7
# BuildOrder seen nodes :  7
# DetectTriangles seen nodes :  7
# EdgeDirector seen nodes :  7
# FunctionQ seen nodes :  13
# GraphTrim seen nodes :  13
# EdgeDirector seen nodes :  13
# FunctionQ seen nodes :  13
# DetectElbows seen nodes :  12
# EdgeDirector seen nodes :  13
# Scale seen nodes :  13
# LabelConnector seen nodes :  13
# FunctionQ seen nodes :  12
# MakeInstructions seen nodes :  13
# SpatialRoot seen nodes :  12
# EdgeDirector seen nodes :  12
# BuildOrder seen nodes :  12
# KDTreeIndex seen nodes :  12
# Rotator seen nodes :  7
# EdgeDirector seen nodes :  7
# BuildOrder seen nodes :  7
# DetectTriangles seen nodes :  7
# EdgeDirector seen nodes :  7
# FunctionQ seen nodes :  13
# GraphTrim seen nodes :  13
# EdgeDirector seen nodes :  13
# FunctionQ seen nodes :  13
# DetectElbows seen nodes :  12
# EdgeDirector seen nodes :  13
# Scale seen nodes :  13
# LabelConnector seen nodes :  13
# FunctionQ seen nodes :  12
# MakeInstructions seen nodes :  13
# creating insturcionts 6198

# %%
RL(sks)
e = gutils.edge_with_id(rn0, 2031118)
ex1, ex2 = e.target.successors(edges=True)

print(e.target.tmps)
n1 = Node(e.source.geom)
n2 = Node(e.target.geom, **e.target.tmps)

n3 = Node(ex1.target.geom)
n4 = Node(ex2.target.geom)

e1 = n1.connect_to(n2, **e.tmps)
e2 = n2.connect_to(n3, **ex1.tmps)
e3 = n2.connect_to(n4, **ex2.tmps)

e2 = sks.align_vertical(e2)
e3 = sks.align_vertical(e3)
print(e1.tmps)
print(e2.tmps)
print(e3.tmps)
for n in [n1, n2, n3, n4]:
    n.geom = gutils.tuplify(n.as_np + 5)
    

res = sks.MakeInstructions()(n1, shrink=-0.05, use_radius=True)
save_instr(res)
# Out:
# {'pt_index': 3332, 'order': 10, 'is_tee': True}
# {'is_pipe': True, 'radius': 0.0688976377952756, 'order': 9}
# {'is_pipe': True, 'radius': 0.0374015748031496, 'order': 14, 'tap_edge': True}
# {'is_pipe': True, 'radius': 0.06889763779527561, 'order': 17}
# 929428 8201580 3773741
# MakeInstructions seen nodes :  4
# creating insturcionts 4
# [[1,
#   929428,
#   257.68469898330824,
#   4.999962020543802,
#   4.971847746250392,
#   252.8500183560248,
#   4.999962185555826,
#   4.9259549739175466,
#   0.16666666666666666],
#  [1,
#   3773741,
#   252.80002060851893,
#   4.999962187262295,
#   4.9754803747826015,
#   252.80002060851893,
#   4.999962187262295,
#   5.342748818168488,
#   0.16666666666666666],
#  [1,
#   8201580,
#   252.75002286112675,
#   4.999962188806639,
#   4.925005763670231,
#   241.76991750883252,
#   4.999962527963154,
#   4.820775467566609,
#   0.16666666666666666],
#  [5, 3401756, 929428, 1, 8201580, 0, 3773741, 0]]

# %%
OFS = 0.067708333
# from src.formats.revit import Cmds
res2 = [[13, 0, 1],
        # [12, "Elbow - Generic", 32, 4, 0, 0, 0, 0, 1, math.pi/2], 
        # [12, "Elbow - Generic", 101, 2, 0, 0, 0, 1, 0, math.pi/2],
        [12, "Elbow - Generic", 69, 0, 0, 0, 0, 1, 0, 0], 
        [12, "Elbow - Generic", 32, -2, 0, 0, 0, 0, 1, -math.pi/2], 
        
        # [revit.Cmds.Pipe.value, 111, -2 + OFS, 0, 10, -OFS, 0, 10 ,1/12],
        [revit.Cmds.Pipe.value, 777, 32, 2, 69, 1, 1/12],
       
        #[revit.Cmds.Connect.value, 32, 1, 111, 0],
        #[revit.Cmds.Connect.value, 111, 1, 69, 0]
       ]
save_instr(res2)
# Out:
# creating insturcionts 4
# [[13, 0, 1],
#  [12, 'Elbow - Generic', 69, 0, 0, 0, 0, 1, 0, 0],
#  [12, 'Elbow - Generic', 32, -2, 0, 0, 0, 0, 1, -1.5707963267948966],
#  [1, 777, 32, 2, 69, 1]]

# %%
RL(sks)
RL(gutils)
# works 
# working = [6617348, 6628663, 26386, 9763633, 4821092, 1163778]
yes = [gutils.edge_with_id(rn0, x) for x in working]

failing = [5297330]
nos = [gutils.edge_with_id(rn0, x) for x in failing]
up = geo.Line(Point(0, 0, 0), Point(0, 0, 1))

def angle_tap(tap_edge):
    eg_in = tap_edge.source.predecessors(edges=True)[0]
    return eg_in.curve.line.angle_to(tap_edge.curve.line)

#print([math.degrees( x.curve.line.angle_to(up)) for x in yes])
#print([sks.vert(x, 0.005) for x in yes])
print([sks.vert(x, 0.005) for x in nos])
print('-----')
# print([math.degrees( angle_tap(x)) for x in yes])
print([math.degrees(  angle_tap(x)) for x in nos])
# Out:
# [False]
# -----
# [89.97456308927791]

# %%
                            
s2s = [[6602847,835700], 
       [2453322, 8398095], 
       [4273177, 3470876] ,
       [3427485, 8669107],
       [8669107, 5767781]  # coupling
      ] 

for i1, i2 in s2s:
    t1 = gutils.edge_with_id(rn0, i1)
    t2 = gutils.edge_with_id(rn0, i2)
    # t1.target.tmps
    print(gutils.norm_angle(t1, t2), sks.similar_dir_abs(t1, t2))
    

# math.degrees( t1.curve.line.angle_to(t2.curve.line))
# Out:
# 89.9999999729977 False
# 0.9191628306328405 False
# 89.9999999980313 False
# 0.4598090741225798 True
# 2.0512035806079028 False

# %%
def copy_translate(node, t=np.array([0, 0, 10])):
    xf = lambda x, kw: Node(gutils.tuplify(x.as_np + t), **kw)
    nd = xf(node, node.tmps)
    for e, n in node.successors(both=True):
        new_nd = xf(n, {})
        nd.connect_to(new_nd, **e.tmps)
    for e, n in node.predecessors(both=True):
        new_nd = xf(n, {})
        new_nd.connect_to(nd, **e.tmps)
    return nd

# %%
# tap = gutils.edge_with_id(rn0, 5851648)
inn = gutils.edge_with_id(rn0, 1407181)
# out = gutils.edge_with_id(rn0, 204995)
tee = copy_translate(inn.target)
print(tee.tmps)
inn2 = tee.predecessors()[0]

res2 = sks.MakeInstructions()(inn2, shrink=-0.05, use_radius=True)
save_instr(res2)
# Out:
# {'pt_index': 3057, 'order': 72, 'is_tee': True}
# MakeInstructions seen nodes :  4
# creating insturcionts 4
# [[1,
#   8181741,
#   468.19801874219564,
#   -55.34417201144305,
#   11.63056683102958,
#   468.1979815857606,
#   -95.09646043286497,
#   11.47420610239293,
#   0.16666666666666666],
#  [1,
#   6378434,
#   468.1979814891446,
#   -95.19645654891363,
#   11.474600793440707,
#   468.19796298409227,
#   -113.74421473890237,
#   11.693983577314778,
#   0.16666666666666666],
#  [1,
#   2961643,
#   468.24798020479204,
#   -95.14648085647212,
#   11.473644759134382,
#   491.41471935124014,
#   -95.15612329084985,
#   11.304673202500316,
#   0.16666666666666666],
#  [5, 675221, 8181741, 1, 6378434, 0, 2961643, 0]]

# %%
RL(sks)
RL(gp)
RL(gutils)
def prslope(node, **kwargs):
    tol = 128
    for x in node.successors(edges=True):
        print(round(12 *gutils.slope(x) * tol) / tol )
    return node
        
rn0.successors(edges=True)[0].curve.line.numpy
prslope(rn0)
# gp.FunctionQ(prslope)(rn0)
# Out:
# 0.046875

# %%
import inspect
RL(src.propogate.propagators)
RL(src.propogate)
RL(gp)
inspect.getmro(gp.GraphTrim)
# Out:
# (src.propogate.propagators.GraphTrim,
#  src.propogate.base.QueuePropogator,
#  object)

# %% [markdown]
# ## TESTING SERVER

# %%
# TEST TEES
RL(sks)

RN = Node((270, 0, 0))
n2 = Node((270, 5, 0), head_tee=True)

n3 = Node((270, 10, 0))
nu = Node((270, 5, 1))

RN.connect_to(n2, is_pipe=True)
n2.connect_to(n3, is_pipe=True)
n2.connect_to(nu, remove_head=True)


r2 = sks.MakeInstructions()(RN, shrink=-0.05, use_radius=True)
r2 = save_instr(r2)
r2
# Out:
# MakeInstructions seen nodes :  4
# [[1, 9175618, 270.0, 0.05, 0.0, 270.0, 4.95, 0.0, 0.16666666666666666]]

# %%
# TEST COUOPLINGS
RL(sks)

RN = Node((275, 0, 0))
n1 = Node((275, 10, 0), is_coupling=True)
n2 = Node((275, 15, 0))

RN.connect_to(n1, is_pipe=True)
n1.connect_to(n2, is_pipe=True)

r2 = sks.MakeInstructions()(RN, shrink=-0.05, use_radius=True)
r2 = save_instr(r2)
r2
# Out:
# MakeInstructions seen nodes :  3
# [[1, 6284211, 275.0, 0.05, 0.0, 275.0, 9.95, 0.0, 0.16666666666666666],
#  [1, 9694699, 275.0, 10.05, 0.0, 275.0, 15.0, 0.0, 0.16666666666666666],
#  [8, 6284211, 1, 9694699, 0]]

# %%
# TEST ELBOWS
RL(sks)

RN = Node((280, 0, 0))
n1 = Node((280, 10, 0), is_elbow=True)
n2 = Node((285, 10, 0), is_elbow=True)
n3 = Node((285, 15, 0))

RN.connect_to(n1, is_pipe=True)
n1.connect_to(n2, is_pipe=True)
n2.connect_to(n3, is_pipe=True)

r2 = sks.MakeInstructions()(RN, shrink=-0.1, use_radius=True)
r2 = save_instr(r2)
r2
# Out:
# MakeInstructions seen nodes :  4
# [[1, 45569, 280.0, 0.1, 0.0, 280.0, 9.9, 0.0, 0.16666666666666666],
#  [1, 7666367, 280.1, 10.0, 0.0, 284.9, 10.0, 0.0, 0.16666666666666666],
#  [1, 3906340, 285.0, 10.1, 0.0, 285.0, 15.0, 0.0, 0.16666666666666666],
#  [4, 45569, 1, 7666367, 0],
#  [4, 7666367, 1, 3906340, 0]]

# %%
RN = Node((280, 0, 0))
r2 = Node((280, 1, 10))
egd = RN.connect_to(r2, is_pipe=True)

RL(sks)
RL(gutils)
sks.is_vertical(egd)
# Out:
# 0.004962809790010847

# %% [markdown]
# ----------------------------------------------

# %%
# todo
def low_line(pts_index):
    lowest_ix = np.argsort(pts_index[:, -1])
    lowest_spr = pts_index[lowest_ix[0:2]]
    return Line(Point(lowest_spr[0]), Point(lowest_spr[1]))


CAD_Line = low_line(pts_ind)
p1, p2 = CAD_Line.points
rot = sks.Rotator(CAD_ANGLE)
cln = CAD_Line.moved(rot.M)


REV_Line = low_line(rvpts_index)

print(CAD_Line.length / REV_Line.length)

viz3.viz(REV_Line, handle='low/rev', thickness=1)
viz3.viz(cln, handle='low/cad', thickness=1)
# Out:
# 0.4724310517187339

# %%
import src.render.render_propogators as rps
import src.process as process
import json
RL(rps)
RL(sks)
RL(process)
SHRINK = -0.05
OUTPATH = '/home/psavine/source/viper/data/out/sks/'

def save_outs(args, pth):
    geom, inds, syms = args
    res = {'geom': geom, 'indicies': inds, 'symbols': syms}
    print(len(geom), len(inds), len(syms))
    st = str(round(time.time(), 0))
    with open('{}to-revit-{}.json'.format(OUTPATH, pth), 'w') as F:
        json.dump(res, F)
        
        
def _prepare(start, end, last=False):
    Shrink = -0.01
    edge = start.edge_to(end)
    radius = edge.get('radius')
    if radius is None:
        radius = 1.
    crv = geom.MepCurve2d(start.geom, end.geom)
    if last is False:
        p1, p2 = crv.extend(Shrink, Shrink).points
    else:
        p1, p2 = crv.extend(Shrink, 0).points

    if math.isnan(p1[0]):
        print(start, end, p1, p2)
    vec = list(p1) + list(p2) + [radius]
    return vec    


def _preparep(start, end, last=False):
    Shrink = -0.01
    edge = start.edge_to(end)
    radius = edge.get('radius')
    if radius is None:
        radius = 1.
    vec = list(start.geom) + list(end.geom) + [radius]
    return vec    


def TO_REVIT(root_nd, n, prep=_preparep):
    anno = sks.Annotator('$create', mapping={'has_head': 3})
    gp.EdgeDirector()(root_nd)
    anno(root_nd)

    gp.BuildOrder()(root_nd)

    print(anno._pos)
    res = process.finalize(root_nd, prep)

    save_outs(res, n)

def TO_REVIT2(root_nd, n):
    anno = sks.Annotator('$create', mapping={'has_head': 3})
    gp.EdgeDirector()(root_nd)
    anno(root_nd)

    gp.BuildOrder()(root_nd)

    print(anno._pos)
    res = process.finalize(root_nd, _prepare)

    save_outs(res, n)

# %%
# Out:
# EdgeDirector seen nodes :  292
# Annotator seen nodes :  292
# BuildOrder seen nodes :  292
# 0
# 291 180 0

# %%
RL(geombase)
pts = []
for msh in train_mesh:
    if msh.category =='Pipes':
        ln = geombase.as_cylinder(msh)
        if ln is not None:
            pts.append(ln.numpy)
rvpts_index = np.concatenate(pts)

# %%
import src.propogate.propagators as gpp
RL(gpp)

def buildo(node, value=-2, **kwargs):
    return node.get('order', -1) == value

def slope(crv):
    npp = crv.numpy
    # print(crv.length)
    z = npp[0, -1] - npp[1, -1]
    
    return np.abs(z / Line(*map(Point, crv.points)).length)



fedge = rn1.successors(edges=True)[0]

n10 = gpp.Where(buildo, edges=True)(fedge, value=10)
n11 = gpp.Where(buildo, edges=True)(fedge, value=11)
n8 = gpp.Where(buildo, edges=True)(fedge, value=8)

print(n8.similar_direction(n11))
print(n8.similar_direction(n10))
print(n10.similar_direction(n8))
# print(n10.direction(n8))

edges__ = [n10, n11, n8]

np.allclose(n10.direction, n10.direction)

[print(np.round(x.direction, 3)) for x in edges__]
preped = [_prepare(x.source, x.target) for x in edges__]
res = [preped[0][0:3], preped[1][0:3], preped[2][3:6]]
for i, r in enumerate(res):
    V.viz_point(r, handle='test/' + str(i), radius=0.04)
# Out:
# False
# False
# False
# [-0.001  1.     0.013]
# [0. 0. 1.]
# [ 0.     1.    -0.008]

# %%
viz3.viz_point(rn1.geom, handle='test')

# %%
scs = rn1.successors(edges=True)
[x.curve.length for x in scs]
scs[1].target.id
Line(*map(Point, scs[1].curve.points)).length
# Out:
# 0.25

# %%
x = [[print(x.curve.length) for x in n.successors(edges=True)] for n in rn1.__iter__()]
# Out:
# 4.424903815802851
# 0.0
# 4.724409448892871
# 0.0
# 4.724416227465029
# 0.0
# 4.724402670148194
# 0.0
# 4.4881889763999965
# 0.0
# 1.4957284255232712
# 0.0
# 2.478527986093234
# 5.669292060701303
# 1.4957555886543963
# 4.682671853122132
# 4.488188976346123
# 0.0
# 4.724395891408776
# 0.0
# 4.724423006181383
# 0.0
# 4.72440944888227
# 0.0
# 4.424903412963972
# 0.0
# 0.067175219912541
# 0.9865987346366425
# 0.07236078501142551
# 2.1760124066530855
# 0.034878687351237996
# 26.190306445110405
# 4.717697120001906
# 0.9564337814230855
# 5.669293752049265
# 1.4958002112352013
# 1.4957740893192808
# 2.478518031069224
# 4.488188976443702
# 0.0
# 4.7244094488386565
# 0.0
# 4.724409448839083
# 0.0
# 4.724409448774793
# 0.0
# 4.424903789235771
# 0.0
# 4.488188976393822
# 0.0
# 4.724409448746627
# 0.0
# 4.724409448799719
# 0.0
# 4.724409448872876
# 0.0
# 4.42490342864997
# 0.0
# 5.669296178601118
# 1.4958606619651829
# 0.9363991779603119
# 1.4958965948616998
# 0.23363305708584128
# 0.37765748035644303
# 0.18956692907133119
# 0.37765748029841023
# 4.488188976393715
# 0.0
# 4.724409448788109
# 0.0
# 4.724409448798654
# 0.0
# 4.724409448824559
# 0.0
# 4.424902391274515
# 0.0
# 4.4881889764235225
# 0.0
# 4.724409448860001
# 0.0
# 4.724409448770018
# 0.0
# 4.724409448764064
# 0.0
# 4.424902728671854
# 0.0
# 1.8897760599917932
# 26.16150198298772
# 0.20534062338771555
# 0.06715962247030373
# 4.679992222155401
# 0.9965476587520543
# 1.4955970793016566
# 5.669275061292631
# 4.488188976366911
# 0.0
# 4.724409448855802
# 0.0
# 4.724409448802348
# 0.0
# 4.724409448836951
# 0.0
# 4.424906803083929
# 0.0
# 2.473782276660298
# 1.4957074343917183
# 4.4881889764043486
# 0.0
# 4.724409448831317
# 0.0
# 4.724409448774211
# 0.0
# 4.72440944885129
# 0.0
# 4.424904665979967
# 0.0
# 5.666760255284589
# 1.3933970313343287
# 1.495883996900292
# 4.32915191918172
# 4.488188976385368
# 0.0
# 4.724409448848057
# 0.0
# 4.724409448789289
# 0.0
# 4.724409448837278
# 0.0
# 4.424902302166999
# 0.0
# 2.785585339577021
# 1.4958456405036153
# 0.19449472947941815
# 0.5800985751239749
# 4.03615329459966
# 1.386897907383071
# 0.15023851057178905
# 0.6826830263489558
# 2.834645669275595
# 0.0
# 3.0708638874509067
# 0.0
# 3.307086614182246
# 0.0
# 4.724409448752398
# 0.0
# 4.724409448823195
# 0.0
# 4.424907368262908
# 0.0
# 4.488186722067503
# 0.0
# 4.724409448856152
# 0.0
# 4.724409448760241
# 0.0
# 4.724409448845024
# 0.0
# 4.424902667243303
# 0.0
# 4.488188976370591
# 0.0
# 4.724409448823344
# 0.0
# 4.724409448743302
# 0.0
# 4.7244094489301185
# 0.0
# 4.424907098401719
# 0.0
# 5.669282139200246
# 1.4958149735538626
# 1.4958649840446037
# 0.9364097558524341
# 4.48818897640687
# 0.0
# 4.724395891492193
# 0.0
# 4.7244230062039065
# 0.0
# 4.724409448833413
# 0.0
# 4.424902389991332
# 0.0
# 0.2336330550131355
# 0.3776574802987339
# 0.18956692916391965
# 0.3776574803247704
# 0.2335982085737677
# 3.3243637462454676
# 1.495992475003406
# 5.6692947687738116
# 4.4881889763715135
# 0.0
# 4.724395891452346
# 0.0
# 4.724423006221556
# 0.0
# 4.724409448838273
# 0.0
# 4.424901628487789
# 0.0
# 5.3540426588803705
# 1.49596095849955
# 1.4959106403767248
# 4.931433769271414
# 4.488188976415155
# 0.0
# 4.724395891405082
# 0.0
# 4.724423006208525
# 0.0
# 4.7244094488144555
# 0.0
# 4.424901957352518
# 0.0
# 0.15199387799853017
# 1.3897423526158306
# 4.488188976362092
# 0.0
# 4.724395891431514
# 0.0
# 4.724423006189269
# 0.0
# 4.724409448873317
# 0.0
# 4.4249024687786696
# 0.0
# 4.488188976388268
# 0.0
# 4.724395891468248
# 0.0
# 4.724423006184878
# 0.0
# 4.724409448804991
# 0.0
# 4.424901719657584
# 0.0
# 4.488188976432937
# 0.0
# 4.7243958914343835
# 0.0
# 4.7244230061873935
# 0.0
# 4.724409448804139
# 0.0
# 4.4249027333680155
# 0.0

# %% [markdown]
# # --------------------------------------------------------------

# %%
for i in range(len(comps_starts)):
    viz3.viz_iter(root_nodes[i], handle='nodec/{}'.format(i),
                  clear=True, opacity=0.3)

# %% [markdown]
# DetectTriangles seen nodes :  330
# DetectElbows seen nodes :  347
# elbows: 28 , tirangles 18

# %%
RL(sks)

RL(geo)
from lib.geo import Line, Point # , Movement
import lib.meshcat.src.meshcat.transformations as txf


def rotator(orienting_edge):
    rnt = np.array([orienting_edge.source.geom, 
                    orienting_edge.target.geom])

    rnt[:, -1] = 0

    norm = Line(Point(rnt[1]), Point(rnt[0]))
    print(norm)
    base = Line(Point(0., 0., 0.), Point(1., 0, 0))
    m = geo.Movement(norm, base)
    
    angle = norm.angle_to(base)
    print(angle)
    return m
    # return -txf.rotation_matrix(angle, [0.,0., 1], rnt[1])[:3, :3]
    

edg = edge_with_id(ROOT, 4438916)
arr = np.asarray([list(edg.source.geom), list(edg.target.geom)])
print(np.round(arr, 3))
print(edg.curve.length)
M = rotator(edg)

print(M.q, M.dr)
p1 = Point(edg.source.geom)
p2 = Point(edg.target.geom)
ln = Line(Point(edg.source.geom), Point(edg.target.geom))


md = ln.moved(M)
print(ln.length, md.length)
# Out:
# [[ 2.42334e+02  0.00000e+00 -1.26000e-01]
#  [ 2.36876e+02  0.00000e+00 -1.78000e-01]]
# 5.4582469151953035
# Line(Point(236.876, 0, 0), Point(242.334, 0, 0))
# 0.0
# None [0. 0. 0.]
# 5.458492828173617 5.458492828173617

# %% [markdown]
# ### Connect Heads

# %% [markdown]
# ## MISC TESTING

# %%
import src.propogate
# RL(src.propogate.base)
RL(sks)

root = edge_with_id(root_nodes[0], 1275321)
nd = root.source
print(root)
sks.EdgeDirectorQ()(nd)
# Out:
# <Edge>:((58.17832921906061, -128.39112719713268, 0.3211833299301574), (57.19465048862049, -124.14188319947925, 0.29480801374617727)), {'is_pipe': True}

# %%
VIZ['nodec'].delete() 
viz3.viz_iter(nd, handle='nodec/0', 
                   opacity=0.3)  

len(list(nd.__iter__(fwd=True, bkwd=True)))
# Out:
# 1158

# %%
sprinks_arr = sprinklers3
sprinks_2d = sprinks_arr[:, 0:2]
sprinks_tree = kdtree.KDTree(sprinks_arr[:, 0:2])

pipe_2d = np.concatenate(plines)[:, 0:2]
pipe_2dtree = kdtree.KDTree( pipe_2d)
tr = sprinks_tree.query_ball_tree(pipe_2dtree, 1)

sprinks_to_pipes = dict()
pipes_to_sprinks = defaultdict(set)
sprinks_to_pipes_d = dict()
for i, x in enumerate(tr):
    if len(x) > 0:
        dists, pipe_ixs = sprinks_tree.query(pipe_2d[x])
        sprinks_to_pipes[i] = x[np.argmin(dists)]
        pipes_to_sprinks[x[np.argmin(dists)]].add(i) 
        sprinks_to_pipes_d[i] = dists[np.argmin(dists)]
# Out:
# array([  391.57757842, -7925.38562256,  1139.87186712])

# %% [markdown]
# ## TRY WITH WHOLE SAT

# %%
headers, data = lines[0:3], lines[3:]

# %%
def dec_sat(bin_line):
    return bin_line.decode('ascii').split(' ')


def recur_bod(ix):
    
    seen = set()
    others = []
    q = [ix]
    while q:
        this_ix = q.pop()
        # print(this_ix)
        if this_ix in seen:
            continue
            
        seen.add(this_ix)
        raw = data[this_ix]
        
        chunks = dec_sat(raw)
        others.append(chunks)
        print(this_ix, chunks)
        for c in chunks:
            if c[0] == '$' and c != '$-1':
                todo = int(c[1:])
                # print('todo', todo)
                q.append(todo) 

    return others
            

# data[108302: 108306]
recur_bod(1)
# Out:
# 1 ['body', '$-1', '-1', '$-1', '$21463', '$-1', '$21464', '#\r\n']
# 21464 ['transform', '$-1', '-1', '1', '0', '0', '0', '1', '0', '0', '0', '1', '-1101197.235013285652', '109246.670983092743', '832.9999939502620236', '1', 'rotate', 'no_reflect', 'no_shear', '#\r\n']
# 21463 ['lump', '$-1', '-1', '$-1', '$-1', '$64713', '$1', '#\r\n']
# 64713 ['shell', '$-1', '-1', '$-1', '$-1', '$-1', '$86505', '$-1', '$21463', '#\r\n']
# 86505 ['face', '$108301', '-1', '$-1', '$-1', '$108302', '$64713', '$-1', '$108303', 'reversed', 'double', 'out', '#\r\n']
# 108303 ['\t0.1691308163470010006', '2', '0.171370211494747321', '3', '\r\n']
# 108302 ['\t0.1624126309037620397', '3', '0.1668914211992546803', '2', '0.1680111187731278544', '2', '0.1685709675600644275', '2', '0.1688508919535327002', '2', '\r\n']
# 108301 ['\t0', '2', '1', '2', '\r\n']
# [['body', '$-1', '-1', '$-1', '$21463', '$-1', '$21464', '#\r\n'],
#  ['transform',
#   '$-1',
#   '-1',
#   '1',
#   '0',
#   '0',
#   '0',
#   '1',
#   '0',
#   '0',
#   '0',
#   '1',
#   '-1101197.235013285652',
#   '109246.670983092743',
#   '832.9999939502620236',
#   '1',
#   'rotate',
#   'no_reflect',
#   'no_shear',
#   '#\r\n'],
#  ['lump', '$-1', '-1', '$-1', '$-1', '$64713', '$1', '#\r\n'],
#  ['shell',
#   '$-1',
#   '-1',
#   '$-1',
#   '$-1',
#   '$-1',
#   '$86505',
#   '$-1',
#   '$21463',
#   '#\r\n'],
#  ['face',
#   '$108301',
#   '-1',
#   '$-1',
#   '$-1',
#   '$108302',
#   '$64713',
#   '$-1',
#   '$108303',
#   'reversed',
#   'double',
#   'out',
#   '#\r\n'],
#  ['\t0.1691308163470010006', '2', '0.171370211494747321', '3', '\r\n'],
#  ['\t0.1624126309037620397',
#   '3',
#   '0.1668914211992546803',
#   '2',
#   '0.1680111187731278544',
#   '2',
#   '0.1685709675600644275',
#   '2',
#   '0.1688508919535327002',
#   '2',
#   '\r\n'],
#  ['\t0', '2', '1', '2', '\r\n']]
